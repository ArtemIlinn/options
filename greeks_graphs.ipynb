# %%
import OptionLib
import pandas as pd
import numpy as np

# %%
df_prices = pd.DataFrame(list(range(101)), columns = ['Spot'])

# %%
for greek in ['delta', 'gamma', 'rho', 'theta', 'vega']:
    OptionLib.greek_plot(df_prices, greek_name=greek, type='both')
